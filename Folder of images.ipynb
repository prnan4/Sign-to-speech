# %%
import os
i = 0
for i in range(0, 25):
    os.mkdir('/Users/nandhinee_pr/sign/data/' + str(i))
    i+= 1

# %%
import csv
import pandas as pd
data = pd.read_csv('/Users/nandhinee_pr/Downloads/sign-language-mnist/sign_mnist_train.csv')
data.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9    ...     pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0     153    ...          207       207       207       207       206
# 1     158    ...           69       149       128        87        94
# 2     187    ...          202       201       200       199       198
# 3     210    ...          235       234       233       231       230
# 4     185    ...           92       105       105       108       133
#
#    pixel780  pixel781  pixel782  pixel783  pixel784
# 0       206       206       204       203       202
# ...

# %%
df = data.loc[[0]]
value =df['label'].values[0]
df.head()
value
# Out:
# 3

# %%
data.shape
# Out:
# (27455, 785)

# %%
data.label.unique()
# Out:
# array([ 3,  6,  2, 13, 16,  8, 22, 18, 10, 20, 17, 19, 21, 23, 24,  1, 12,
#        11, 15,  4,  0,  5,  7, 14])

# %%
from PIL import Image
import numpy as np
import cv2
count = 0

for int1 in range(0,27454):
    df = data.loc[[int1]]
    label =df['label'].values[0]
    
    i = 1
    temp = ''
    while(i<=784):
        value =df['pixel' + str(i)].values[0]
        temp += str(value) + ','
        i+=1
    temp=temp[:-1]
    
    li = list(temp.split(",")) 

    listoflists = []
    temp_list = []

    for i in range(0,len(li)):
        li[i] = int(li[i])

    i =0
    k =0
    for i in range(0,28):
        temp_list = []
        j = 0
        while j <28:
            temp_list.append(li[k])
            k+=1
            j+=1
        listoflists.append(temp_list)
        
    pixels = listoflists
    array = np.array(pixels, dtype=np.uint8)
    new_image = Image.fromarray(array)
    
    new_image.save('/Users/nandhinee_pr/sign/data/' + str(label) + '/img' + str(count) + '.jpg')
    count +=1
